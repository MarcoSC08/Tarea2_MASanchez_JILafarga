# %% [markdown]
# <img style="float: left; margin: 30px 15px 15px 15px;" src="https://pngimage.net/wp-content/uploads/2018/06/logo-iteso-png-5.png" width="300" height="500" />
#
#
# ### <font color='navy'> Simulación de procesos financieros.
#
# **Nombres:** Marco Antonio Sánchez Covarrubias. Jesus Iván Lafarga.
#
# **Fecha:** 09 de Septiembre del 2021.
#
# **Expediente** : 720268, 708989.
#
# **Profesor:** Oscar David Jaramillo Zuluaga.
#
# **Link Github**: https://github.com/MarcoSC08/Tarea2_MASanchez_JILafarga
#
# # Tarea 2: Clase 4

# %% [markdown]
# ## Optimización con Programación
# > Serie de ejercicios para practicar las habilidades de utilizar funciones y optimización por medio de programación.

# %% [markdown]
# ![imagen.png](attachment:imagen.png)

# %% [markdown]
# Código de solución estudiante 1 Marco

# %%
# Código de solución estudiante 1
import numpy as np
orders = [ ["34587", "Learning Python, Mark Lutz", 4, 40.95], 
           ["98762", "Programming Python, Mark Lutz", 5, 56.80], 
           ["77226", "Head First Python, Paul Barry", 3,32.95],
           ["88112", "Einführung in Python3, Bernd Klein", 3, 24.99]]

p= lambda x,y:x*y
def increase(value):
    if(value<100):
        value +=10
    return value

x=list(map(increase,[p(orders[i][2],orders [i][3]) for i in np.arange(len(orders))]))
result=list(map(lambda x,y: (x[0],y),orders,x))
result
# Out:
# [('34587', 163.8),
#  ('98762', 284.0),
#  ('77226', 108.85000000000001),
#  ('88112', 84.97)]

# %%
import numpy as np
import matplotlib.pyplot as plt
from collections import Counter
from collections import deque
from functools import reduce
import pandas as pd
import functools

# %% [markdown]
# Código de solución estudiante 2 Ivan

# %%
# Código de solución estudiante 2
orders = [ ["34587", "Learning Python, Mark Lutz", 4, 40.95], 
           ["98762", "Programming Python, Mark Lutz", 5, 56.80], 
           ["77226", "Head First Python, Paul Barry", 3,32.95],
           ["88112", "Einführung in Python3, Bernd Klein", 3, 24.99]]

# %%
o = list(map(lambda x: (x[0], x[2]*x[3] if x[2]*x[3] >= 100 else x[2]*x[3]+10 ), orders))
o # La orden y precios totales
# Out:
# [('34587', 163.8),
#  ('98762', 284.0),
#  ('77226', 108.85000000000001),
#  ('88112', 84.97)]

# %% [markdown]
# ### Respuesta planteada en el ejercicio usando (markdown)
#  La respuesta es .........

# %% [markdown]
# ### Ejercicio 2:
# 2. La misma librería, pero esta vez trabajamos en una lista diferente. Las sublistas de nuestras listas se ven así:
# [número de orden, (número de artículo, cantidad, precio por unidad), ... (número de artículo, cantidad, precio por unidad)]
#
# `orders = [[1, ("5464", 4, 9.99), ("8274",18,12.99), ("9744", 9, 44.95)],
# 	       [2, ("5464", 9, 9.99), ("9744", 9, 44.95)],
# 	       [3, ("5464", 9, 9.99), ("88112", 11, 24.99)],
#            [4, ("8732", 7, 11.99), ("7733",11,18.99), ("88112", 5, 39.95)] ]`
#
# Escriba un programa que devuelva una lista de dos tuplas que tengan la información de (número de pedido, cantidad total de pedido). Utilice la función `Reduce`. Recuerde el precio del pedido del producto debe aumentarse en 10€ si el valor de la orden es inferior a 100,00 €.

# %% [markdown]
# Código de solución estudiante 1 Marco

# %%
# Código de solución estudiante 1
from functools import reduce
orders2 = [[1, ("5464", 4, 9.99), ("8274",18,12.99), ("9744", 9, 44.95)], 
          [2, ("5464", 9, 9.99), ("9744", 9, 44.95)],
          [3, ("5464", 9, 9.99), ("88112", 11, 24.99)],
          [4, ("8732", 7, 11.99), ("7733",11,18.99), ("88112", 5, 39.95)] ]

#f=reduce(lambda x1,x2: x1*x2,orders2)
def nwp(s):
    return s[1] * s[2] if s[2] * s[1] >= 100 else s[2] * s[1] + 10
total = [[nwp(orders2[i][j]) for j in range(1, len(orders2[i]))]
         for i in range(len(orders2))]
[(orders2[i][0], reduce(lambda t, u: t * u, total[i])) for i in range(len(total))]
# Out:
# [(1, 4725810.37476),
#  (2, 40418.5905),
#  (3, 27464.259899999997),
#  (4, 3919302.280575)]

# %% [markdown]
# Código de solución estudiante 2 Ivan

# %%
# Código de solución estudiante 2
orders = [[1, ("5464", 4, 9.99), ("8274",18,12.99), ("9744", 9, 44.95)], 
          [2, ("5464", 9, 9.99), ("9744", 9, 44.95)],
          [3, ("5464", 9, 9.99), ("88112", 11, 24.99)],
          [4, ("8732", 7, 11.99), ("7733",11,18.99), ("88112", 5, 39.95)] ]
otwo = list(map(lambda x: (x[0], functools.reduce(lambda x,y: x+y, list(map(lambda y:y[1]*y[2] if y[1]*y[2]>100 else y[1]*y[2]+10, x[1:])))),orders))
otwo
# Out:
# [(1, 688.3299999999999),
#  (2, 504.46000000000004),
#  (3, 374.79999999999995),
#  (4, 502.57)]

# %% [markdown]
# ### Respuesta planteada en el ejercicio usando (markdown)
#  La respuesta es .........

# %% [markdown]
# ### Ejercicio 3:
# 3. Resolver los anteriores ejercicios usando pandas (DataFrame)

# %% [markdown]
# Código de solución estudiante 1 Marco

# %%
# Código de solución estudiante 1
import pandas as pd 
orders=pd.DataFrame(orders)


orders["Total"]=(orders.iloc[:,2]*orders.iloc[:,3]).apply(lambda x:x if x>=100 else x+10)


orders.drop([1, 2,3], axis=1, inplace=True)
orders
# Out:
#        0   Total
# 0  34587  163.80
# 1  98762  284.00
# 2  77226  108.85
# 3  88112   84.97

# %% [markdown]
# Código de solución estudiante 2 Ivan

# %%
# Código de solución estudiante 2
orders = [ ["34587", "Learning Python, Mark Lutz", 4, 40.95], 
           ["98762", "Programming Python, Mark Lutz", 5, 56.80], 
           ["77226", "Head First Python, Paul Barry", 3,32.95],
           ["88112", "Einführung in Python3, Bernd Klein", 3, 24.99]]


datf = pd.DataFrame(orders, columns = ["No. order", "name", "Quantity","Price"])
datf["Q*P"]=datf["Quantity"]*datf["Price"]
datf["Final_price"]=datf["Q*P"].apply(lambda x: x if x >= 100 else x+10)
datf.drop(["name","Quantity","Price","Q*P"], axis=1).set_index("No. order")
# Out:
#            Final_price
# No. order
# 34587           163.80
# 98762           284.00
# 77226           108.85
# 88112            84.97

# %%
#Ejercicio 2:
orders = [[1, ("5464", 4, 9.99), ("8274",18,12.99), ("9744", 9, 44.95)], 
          [2, ("5464", 9, 9.99), ("9744", 9, 44.95)],
          [3, ("5464", 9, 9.99), ("88112", 11, 24.99)],
          [4, ("8732", 7, 11.99), ("7733",11,18.99), ("88112", 5, 39.95)] ]

df = pd.DataFrame(orders, columns = ["Número", "Orden A", "Orden B","Orden C"])
df.replace((None,None,None), np.zeros((3,), dtype = "i,i,i"),inplace=True)

df["FA"]= df["Orden A"].apply(lambda x: (x[1]*x[2]if x[1]*x[2] >= 100 else x[1]*x[2]+10) ,orders)
df["FB"]= df["Orden B"].apply(lambda x: (x[1]*x[2]if x[1]*x[2] >= 100 else x[1]*x[2]+10),orders)
df["FC"]= df["Orden C"].apply(lambda x: (x[1]*x[2]) ,orders)
df["Final"] = df["FA"]+df["FB"]+df["FC"] 
df
df.drop(["Orden A","Orden B","Orden C","FA","FB","FC"], axis=1).set_index("Número")
# Out:
#          Final
# Número
# 1       688.33
# 2       504.46
# 3       374.80
# 4       502.57

# %% [markdown]
# ### Respuesta planteada en el ejercicio usando (markdown)
#  La respuesta es .........

# %% [markdown]
# ### Ejercicio 4:
# 4. Use filter to eliminate all words that are shorter than 4 letters from a list of words
# `list='the notion of a lambda function goes all the way back to the origin of computer science'`

# %% [markdown]
# Código de solución estudiante 1 Marco

# %%
# Código de solución estudiante 1
lista="the notion of a lambda function goes all the way back to the origin of computer science"
f4 = lambda x: len(x) >= 4
x = list(filter(f4,lista.split()))
x
# Out:
# ['notion',
#  'lambda',
#  'function',
#  'goes',
#  'back',
#  'origin',
#  'computer',
#  'science']

# %% [markdown]
# Código de solución estudiante 2 Ivan

# %%
# Código de solución estudiante 2
w="the notion of a lambda function goes all the way back to the origin of computer science"
Palabras = list(filter(lambda x: (len(x)>=4), w.split()))
print("Palabras con 4 o más letras:",Palabras)
# Out:
# Palabras con 4 o más letras: ['notion', 'lambda', 'function', 'goes', 'back', 'origin', 'computer', 'science']

# %% [markdown]
# ### Respuesta planteada en el ejercicio usando (markdown)
#  La respuesta es .........

# %% [markdown]
# ### Ejercicio 5:
# 5. Use filter to determine the percentage of Fahrenheit temperatures in a list are within the range 32 to 80

# %% [markdown]
# Código de solución estudiante 1 Marco

# %%
# Código de solución estudiante 1
np.random.seed(55555)
temperatures = np.random.uniform(25,110,30)
temp5 = (list(filter(lambda x:32
                    <= x <= 80, 
                    temperatures)))
print("The percentage of Fahrenheit temperatures in a list within the range 32 to 80 are: ", 
      len(temp5)*100/len(temperatures), "%")
# Out:
# The percentage of Fahrenheit temperatures in a list within the range 32 to 80 are:  46.666666666666664 %

# %% [markdown]
# Código de solución estudiante 2 Ivan

# %%
# Código de solución estudiante 2
np.random.seed(55555)
temperatures = np.random.uniform(25,110,30)

temp = list(filter(lambda x: 32 <= x <= 80, temperatures))

p = len(temp)/len(temperatures)
print("El % de temp está entre 32 y 80 Fahrenheit el cual da", p*100,"%")

#me gustaria acotar mi respuesta de porcentaje a 2 decimas profe me gustaria si pudiera darme retroalimentacion en caso de que se pueda
# Out:
# El % de temp está entre 32 y 80 Fahrenheit el cual da 46.666666666666664 %

# %% [markdown]
# ### Respuesta planteada en el ejercicio usando (markdown)
#  La respuesta es .........

# %% [markdown]
# ### Ejercicio 6:
# 6. Use reduce to find the lower left corner (minimum x and minimum y value) for a list of point locations
# > **Hint**: Explore the command `np.minimum.reduce` [link](https://docs.scipy.org/doc/numpy/reference/generated/numpy.ufunc.reduce.html)

# %% [markdown]
# Código de solución estudiante 1 Marco

# %%
# Código de solución estudiante 1
np.random.seed(55555)
point_xy = np.random.randint(0,100,[30,2])
np.minimum.reduce(point_xy)
# Out:
# array([0, 2])

# %% [markdown]
# Código de solución estudiante 2 Ivan

# %%
# Código de solución estudiante 2
np.random.seed(55555)
point_xy = np.random.randint(0,100,[30,2])
#print(point_xy)

# %%
resultado = reduce(lambda x,y: (min(point_xy[:,0]),min(point_xy[:,1])) ,point_xy)
print("The lower left corner is:",np.array(resultado))
# Out:
# The lower left corner is: [0 2]

# %% [markdown]
# ### o tambien puede ser

# %%
# usando el Hint
np.minimum.reduce(point_xy)
# Out:
# array([0, 2])
